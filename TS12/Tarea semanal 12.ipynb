# %% [markdown]
# # Tarea semanal 12
# ## Martín Deleón
#
# ### Consignas:
#
# En esta tarea se solicitó la resolución de los siguientes ejercicios:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Ejercicio 1
# #### Analisis en papel
#
#
# A continuación se encuentra el análisis realizado en papel

# %%
from IPython.display import IFrame
IFrame("TS12_Ej1.pdf", width= 1000, height= 800)

# %% [markdown]
# #### Análisis numérico

# %%
from pytc2.sintesis_dipolo import remover_polo_dc, remover_polo_infinito
from pytc2.general import print_latex, print_subtitle, a_equal_b_latex_s
from pytc2.remociones import remover_polo_jw, remover_valor_en_infinito, remover_valor_en_dc, remover_polo_sigma
import math
import sympy as sp
import numpy as np

# %%
s = sp.symbols('s', complex = True)

Z11 = (s**3 + 2*s)/(2*s**2 + 1)
Z11 = sp.nsimplify(Z11)

print_latex(a_equal_b_latex_s('Z11(s)', Z11))
# Out:
# $\displaystyle Z11(s)=\frac{s^{3} + 2 s}{2 s^{2} + 1}$

# %%
# Remocion parcial en cero para llevar el cero a 1/4

Y2, YL1 = remover_polo_dc(1/Z11, omega_zero= sp.Rational(1/4))

print_latex(a_equal_b_latex_s('ZL1', 1/YL1))
print_latex(a_equal_b_latex_s('Y2', Y2))
# Out:
# $\displaystyle ZL1=\frac{31 s}{14}$
# $\displaystyle Y2=\frac{3 \cdot \left(16 s^{2} + 1\right)}{31 s \left(s^{2} + 2\right)}$

# %%
# Removemos el polo finito en 1/4

Z3, Zt, Lt, Ct = remover_polo_jw(1/Y2, omega= sp.Rational(1/4), isImpedance= True)


print_latex(a_equal_b_latex_s('Zt', Zt))
print_latex(a_equal_b_latex_s('Lt', Lt))
print_latex(a_equal_b_latex_s('Ct', Ct))
print_latex(a_equal_b_latex_s('Z3', Z3))
# Out:
# $\displaystyle Zt=\frac{961 s}{768 \left(s^{2} + \frac{1}{16}\right)}$
# $\displaystyle Lt=\frac{961}{48}$
# $\displaystyle Ct=\frac{768}{961}$
# $\displaystyle Z3=\frac{31 s}{48}$

# %% [markdown]
# Podemos ver que luego de la última remoción nos queda una función que sabemos que, por su expresión, sabemos que es un inductor. Por condición de medición, invertimos y removemos el inductor quedando este en derivación.

# %% [markdown]
# #### Análisis circuital

# %% [markdown]
# Circuito a simular:
#
# ![image.png](attachment:image.png)
#
# En la siguiente imágen podemos ver la transferencia obtenida mediante el circuito:
#
# ![image-2.png](attachment:image-2.png)
#
# En la imágen se puede ver que a 1Hz obtenemos 3dB de atenuación. Tambien podemos ver el cero en 0,25Hz en la siguiente imágen.
#
# ![image-3.png](attachment:image-3.png)
#
# Tambien podemos ver si los parámetros del circuito cumplen, a pesar de que si la transferencia cumplió, los parámetros deberian cumplir tambien.
#
# ![image-4.png](attachment:image-4.png)
#
# En este caso si vamos al papel, vemos que el parámetro $Z11$ tiene un polo en $\frac{1}{\sqrt2}$ al igual que en infinito.
#
# Con esta última verificación podemos estar seguros de que sintetizamos correctamente el circuito.
# Como dato extra la resistencia de un valor elevado en el circuito esta únicamente para poder ver los parámetros, pero no forma parte del mismo.
